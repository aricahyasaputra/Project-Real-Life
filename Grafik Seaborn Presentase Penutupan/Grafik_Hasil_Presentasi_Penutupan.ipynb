# %% [markdown]
# <a href="https://colab.research.google.com/github/aricahyasaputra/Project-Real-Life/blob/main/Grafik%20Seaborn%20Presentase%20Penutupan/Grafik_Hasil_Presentasi_Penutupan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# memanggil modul Pandas and Seaborn  
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
from google.colab import files

# %%
#plt.figure(figsize=(12,8))
nama = ["Line Transek 1", "Line Transek 2", "Line Transek 3"]
jumlah = [18.63, 8.63, 5.36]
color = ["cornflowerblue", "orange", "darkgrey"]
df = pd.DataFrame(list(zip(nama, jumlah)),
               columns =['Name', 'val'])
ax = sns.barplot(x='Name', y='val', data=df, palette=color)
ax.set(xlabel=None, ylabel=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.yaxis.set_major_formatter(PercentFormatter(100))
for p in ax.patches:
        ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.40, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black')
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

change_width(ax, .20)
ax.set(ylim=(0, 20))
plt.legend([],[], frameon=False)

plt.savefig('name.png',bbox_inches='tight')
files.download('name.png')

# %%
plt.figure(figsize=(16,10))
#$\it{text you want to show in italics}$
nama = ["$\it{Thalassia}$ $\it{hemprichii}$", "$\it{Cymodocea}$ $\it{rotundata}$", "$\it{Halophila}$ $\it{ovalis}$", "$\it{Halodule}$ $\it{uninervis}$", "$\it{Syringodium}$ $\it{isoetifolium}$", "$\it{Enhalus}$ $\it{acoroides}$", "$\it{Cymodocea}$ $\it{serrulata}$", "$\it{Halodule}$ $\it{pinifolia}$", "Grand total"]
jumlah = [6.02, 25.93, 0.94, 0, 0.75, 4.85, 0, 0.90, 5.14]
color = ["cornflowerblue", "orange", "darkgrey", "fuchsia", "darkorchid", "limegreen", "aqua", "y", "magenta"]
df = pd.DataFrame(list(zip(nama, jumlah)),
               columns =['Name', 'val'])
ax = sns.barplot(x='Name', y='val', data=df, palette=color)
ax.set(xlabel=None, ylabel=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.yticks([0, 2.5, 5, 7.5, 10, 12.5, 15, 17.5, 20, 22.5, 25, 27.5, 30])
ax.yaxis.set_major_formatter(PercentFormatter(100))
for p in ax.patches:
        ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.40, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black')
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

change_width(ax, .20)
#ax.set(ylim=(0, 30))
plt.rcParams['text.usetex'] = False
plt.legend([],[], frameon=False)

plt.savefig('sengkedua-revisi1.png',bbox_inches='tight')
files.download('sengkedua-revisi1.png')
